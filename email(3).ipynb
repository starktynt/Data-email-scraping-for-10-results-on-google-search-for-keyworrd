# %%
# !gdown --id 1xvOhxYQ-NcC6nO1Ghkj_mZ2SO9SjQQ0r
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xvOhxYQ-NcC6nO1Ghkj_mZ2SO9SjQQ0r
# To: /content/source.xlsx
# 100% 75.8k/75.8k [00:00<00:00, 65.0MB/s]

# %%
import pandas as pd 
df = pd.read_excel("source.xlsx")

# %%
from urllib.error import HTTPError

# %%
df.head()
# Out:
#                      Denominação social  URLs not to scrape
# 0  1/2 DE PALAVRAS - APOIO ESCOLAR, LDA  www.portugalio.com
# 1         100% Genial, Unipessoal, Lda.          www.pai.pt
# 2                             1013, LDA      www.hotfrog.pt
# 3             1stLegacy Consulting, Lda                etc.
# 4      2045 - Empresa de Segurança S.A.                 NaN

# %%
ass = []
for i in df:
  ass.append(i)

# %%
var = list(df[ass[0]])

# %%
no_scrape = list(df[ass[1]])

# %%
var[0]
# Out:
# '1/2 DE PALAVRAS - APOIO ESCOLAR, LDA'

# %%
no_scrape = no_scrape[:3]

# %%
import requests, lxml
from bs4 import BeautifulSoup

headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3538.102 Safari/537.36 Edge/18.19582"
}
noval = no_scrape
def get_link(varr):
  params = {
    'q': varr+" contactos",  # search query
    'hl': 'en',                # language
    'num': '17'               # number of results
  }


  html = requests.get('https://www.google.pt/search', headers=headers, params=params)
  soup = BeautifulSoup(html.text, 'lxml')
  link_lis = []
  
  # container with all needed data
  for result in soup.select('.tF2Cxc'):
    link = result.select_one('.yuRUbf a')['href']
    domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))
    count = 0
    for yx in noval:
      
      if domain_name in str(yx) :
        count +=1
    if count==0:
      if "pdf" in link:
        x=0
      else:
        link_lis.append(link)

    #displayed_link = result.select_one('.TbwUpd.NJjxre').text

    
    #domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))

  print(link_lis[:10])
    #print(displayed_link)
    #print(domain_name)
    #print('---------------')

  return link_lis[:10]

# %%
from bs4 import BeautifulSoup
from requests import get
import re

def mail_id(link):
  ans = []
  req = urllib.request.Request(link,headers={
        'User-Agent':"PostmanRuntime/7.6.0"
    })
  try:
      html = urllib.request.urlopen(req)
  except HTTPError as e:
      content = e.read()
  soup = BeautifulSoup(html)
 

  exp = re.compile(r"(?:.*?='(.*?)')")
  # Find any element with the mail icon
  for icon in soup.findAll("i", {"class": "icon-mail"}):
      # the 'a' element doesn't exist, there is a script tag instead
      script = icon.next_sibling
      # the script tag builds a long array of single characters- lets gra
      chars = exp.findall(script.text)
      output = []
      # the javascript array is iterated backwards
      for char in reversed(list(chars)):
          # many characters use their ascii representation instead of simple text
          if char.startswith("|"):
              output.append(chr(int(char[1:])))
          else:
              output.append(char)
      # putting the array back together gets us an `a` element
      link = BeautifulSoup("".join(output))
      email = link.findAll("a")[0]["href"][8:]
      # the email is the part of the href after `mailto: `
      print(email)
      ans.extend(email)

  mailtos = soup.select('a[href^=mailto]')
  for i in mailtos:
    pattern = '\".*\"'
    s = re.findall(pattern,str(mailtos[0]))
    s = re.sub('\"',"" ,s[0])
    s = re.sub("mailto:","",s)
    match = re.search(r'[\w.+-]+@[\w-]+\.[\w.-]+', s)
    try:
      xxx = match.group(0)
      
    except:
      xxx=s
    
    ans.append(xxx)


  return ans

# %%
import re
def mail_find(line):
  #line = "should we use regex more often? let me know at  321dsasdsa@dasdsa.com.lol"
  match = re.search(r'[\w.+-]+@[\w-]+\.[\w.-]+', line)
  try:
    xxx = match.group(0)
    return xxx
  except:
    return ""

# %% [markdown]
# maindriver

# %%
import urllib
def find_mail(link , xxxx):

  domain_name = ''.join(re.findall(r'^(?:https?:\/\/)?(?:[^@\/\n]+@)?(?:www\.)?([^:\/?\n]+)', link))
  #print(domain_name)
  extra=[]
  req = urllib.request.Request(link,headers={
        'User-Agent':"PostmanRuntime/7.6.0"
    })
  try:
      html = urllib.request.urlopen(req)
  except HTTPError as e:
      content = e.read()

  res_list = []
  html_list = []

  lis=[]
  for line in html:
      
      html_list.append(line) 

  try:
    req = urllib.request.Request(link,headers={
          'User-Agent':"PostmanRuntime/7.6.0"
    })
    try:
        html = urllib.request.urlopen(req)
    except HTTPError as e:
        content = e.read()


    soup = BeautifulSoup(html)
      #soup = BeautifulSoup(content, "lxml")

    exp = re.compile(r"(?:.*?='(.*?)')")
    # Find any element with the mail icon
    for icon in soup.findAll("i", {"class": "icon-mail"}):
        # the 'a' element doesn't exist, there is a script tag instead
        script = icon.next_sibling
        # the script tag builds a long array of single characters- lets gra
        chars = exp.findall(script.text)
        output = []
        # the javascript array is iterated backwards
        for char in reversed(list(chars)):
            # many characters use their ascii representation instead of simple text
            if char.startswith("|"):
                output.append(chr(int(char[1:])))
            else:
                output.append(char)
        # putting the array back together gets us an `a` element
        link = BeautifulSoup("".join(output))
        email = link.findAll("a")[0]["href"][8:]
        # the email is the part of the href after `mailto: `
        print(email)
        lis.extend(email)
  except :
    x = 0


  try:
    for line in html_list:
      if b'@' in line:
        #line = line.replace(b'<img id="video_jacket_img', b'').replace(b'</td>', b'')
        try:
          line = line.strip().decode()
        except:
          line = line.decode("latin-1")
        line = mail_find(line)
        
        if line!="":
          lis.append(line)

    if xxxx == False :

      for line in html_list:
        if bytes(domain_name, 'utf-8') in line:
          #line = line.replace(b'<img id="video_jacket_img', b'').replace(b'</td>', b'')
          
          try:
            line = line.strip().decode()
          except:
            line = line.decode("latin-1")
          line = re.search("(?P<url>https?://[^\s]+)", line).group("url")
          line = re.sub("\".*" , "" , line)
          #line = mail_find(line)
          #print("------",line)
          extra.append(line)


  except:
    x=0
  if len(extra) >=5:
    extra = extra[:5]
  return lis , extra

# %%
no_scrape[1]
# Out:
# 'www.pai.pt'

# %%
data={
    "name":[],
    "url_1":[],
    "url_2":[],
    "url_3":[],
    "url_4":[],
    "url_5":[],
    "url_6":[],
    "url_7":[],
    "url_8":[],
    "url_9":[],
    "url_10":[]

}

# %%
data
# Out:
# {'name': [],
#  'url_1': [],
#  'url_10': [],
#  'url_2': [],
#  'url_3': [],
#  'url_4': [],
#  'url_5': [],
#  'url_6': [],
#  'url_7': [],
#  'url_8': [],
#  'url_9': []}

# %%
from tqdm.notebook import tqdm_notebook
import time




for i in tqdm_notebook(range(10)):
  try:
    
    linkss = get_link(var[i])
    data["name"].append(var[i])
    data["name"].append("emails found")
    for ids in range(len(linkss)) :
      stri = "url_"+str(ids+1)
      try :
        emailss ,extras = find_mail(linkss[ids] , False)
        if len(extras)!=0:
          for j in extras[:2]:
            try:
              extra_mail , xyz = find_mail(j , True)
              emailss.extend(extra_mail)
            except:
              continue

        data[stri].append(linkss[ids])
        data[stri].append(emailss)
      except:
        data[stri].append(linkss[ids])
        data[stri].append("NA")

  except :
    continue
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ['https://www.ummeiodepalavras.pt/', 'https://www.imt-ip.pt/sites/IMTT/Portugues/TransportesRodoviarios/PesquisaEntidadesFormadoras/Paginas/12dePalavras-ApoioEscolarLda.aspx', 'https://www.imt-ip.pt/sites/IMTT/Portugues/TransportesRodoviarios/PesquisaEntidadesFormadoras/Lista-san%C3%A7%C3%B5es-aplicadas-Entidades-Formadoras/Paginas/12dePalavras-ApoioEscolar,Lda.aspx', 'https://empresite.jornaldenegocios.pt/1-2-PALAVRAS-APOIO-ESCOLAR.html', 'https://ja-jp.facebook.com/www.ummeiodepalavras.pt/', 'https://www.net-empregos.com/formacao_detalhe.asp?ID=30259', 'https://www.net-empregos.com/formacao_detalhe.asp?ID=14405', 'https://local.infobel.pt/PT100768411-212121722/1_2_de_palavras_apoio_escolar-fernao_ferro.html', 'https://www.schoolandcollegelistings.com/XX/Unknown/176244119124664/Um-Meio-de-Palavras', 'https://educacao-e-formacao.webnode.pt/']
# ['https://100genial.com/', 'https://empresite.jornaldenegocios.pt/100-GENIAL.html', 'https://www.einforma.pt/servlet/app/portal/ENTP/prod/ETIQUETA_EMPRESA_TELEFONE/nif/509889824/telefone/266098020/', 'https://www.ecoalentejocentral.pt/empresas-aderentes/item/387-100-genial-unipessoal-lda', 'https://www.racius.com/100-genial-unipessoal-lda/', 'https://imoveisportugal.info/empresa-100-genial-unipessoal-em-beja-1272', 'https://docplayer.com.br/3762782-Areas-de-acreditacao-entidade-i-dt-empreendedorismo-internacionalizacao-inovacao-509889824-100-genial-unipessoal-lda.html', 'http://100desperdicios.com/contactos_11.php?pg=11', 'https://issuu.com/cempalavras.pt/docs/listagem_gec_2020', 'https://1library.org/document/qopd00mz-areas-acreditacao-entidade-empreendedorismo-internacionalizacao-inovacao-genial-unipessoal.html']

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c5d84736ba45> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#                                    name  ...                                             url_10
# 0  1/2 DE PALAVRAS - APOIO ESCOLAR, LDA  ...            https://educacao-e-formacao.webnode.pt/
# 1                          emails found  ...                                                 []
# 2         100% Genial, Unipessoal, Lda.  ...  https://www.casagenial.pt/es/imoveis/house-t3-...
# 3                          emails found  ...  [leaflet@1.0.1, leaflet@1.0.1, leaflet@1.0.1, ...
# 4                             1013, LDA  ...  https://ranking-empresas.dinheirovivo.pt/CLINI...
# 5                          emails found  ...  [logo-einforma-sm@2x.png, logo-einforma-sm@2x....
#
# [6 rows x 11 columns]

# %%
df1
# Out:
#                                    name  ...                                             url_10
# 0  1/2 DE PALAVRAS - APOIO ESCOLAR, LDA  ...  https://netforce.iefp.pt/pt-pt/wpg/HOMCU/WPG_M...
# 1                          emails found  ...  [coordenadora@ummeiodepalavras.pt, coordenador...
# 2         100% Genial, Unipessoal, Lda.  ...  https://www.casagenial.pt/es/imoveis/house-t3-...
# 3                          emails found  ...                                                 NA
#
# [4 rows x 11 columns]

# %%
get_link(var[1])
# Out:
# https://100genial.com/
# https://empresite.jornaldenegocios.pt/100-GENIAL.html
# https://www.einforma.pt/servlet/app/portal/ENTP/prod/ETIQUETA_EMPRESA_TELEFONE/nif/509889824/telefone/266098020/
# https://www.ecoalentejocentral.pt/empresas-aderentes/item/387-100-genial-unipessoal-lda
# https://www.racius.com/100-genial-unipessoal-lda/
# https://imoveisportugal.info/empresa-100-genial-unipessoal-em-beja-1272
# https://primegroup.pt/wp-content/uploads/2021/09/Certificado-Qualidade.pdf
# https://docplayer.com.br/3762782-Areas-de-acreditacao-entidade-i-dt-empreendedorismo-internacionalizacao-inovacao-509889824-100-genial-unipessoal-lda.html
# http://100desperdicios.com/contactos_11.php?pg=11
# https://www.arbitragemauto.pt/media/Adesoes-A-Z.pdf
# ['https://100genial.com/',
#  'https://empresite.jornaldenegocios.pt/100-GENIAL.html',
#  'https://www.einforma.pt/servlet/app/portal/ENTP/prod/ETIQUETA_EMPRESA_TELEFONE/nif/509889824/telefone/266098020/',
#  'https://www.ecoalentejocentral.pt/empresas-aderentes/item/387-100-genial-unipessoal-lda',
#  'https://www.racius.com/100-genial-unipessoal-lda/',
#  'https://imoveisportugal.info/empresa-100-genial-unipessoal-em-beja-1272',
#  'https://primegroup.pt/wp-content/uploads/2021/09/Certificado-Qualidade.pdf',
#  'https://docplayer.com.br/3762782-Areas-de-acreditacao-entidade-i-dt-empreendedorismo-internacionalizacao-inovacao-509889824-100-genial-unipessoal-lda.html',
#  'http://100desperdicios.com/contactos_11.php?pg=11',
#  'https://www.arbitragemauto.pt/media/Adesoes-A-Z.pdf']

# %%
df1.to_excel("extraction.xlsx")

# %%
from google.colab import files
files.download("extraction.xlsx")

# %%
import pandas as pd 
dff = pd.read_excel("extraction.xlsx")

# %%
dff.head()
# Out:
#                      Denominação social        Emails  ... Unnamed: 15 Unnamed: 16
# 0  1/2 DE PALAVRAS - APOIO ESCOLAR, LDA  url searched  ...         NaN         NaN
# 1                                   NaN  emails found  ...         NaN         NaN
# 2         100% Genial, Unipessoal, Lda.  url searched  ...         NaN         NaN
# 3                                   NaN  emails found  ...         NaN         NaN
# 4                             1013, LDA  url searched  ...         NaN         NaN
#
# [5 rows x 17 columns]

# %%
find_mail("https://www.net-empregos.com/formacao_detalhe.asp?ID=30259" , False)
# Out:
# ([], [])

# %%
ls = urllib.request.urlopen("https://www.net-empregos.com/formacao_detalhe.asp?ID=30259")

# %%
bin = []
for i in ls :
  bin.append(i)

# %%
for i in bin:
  if b'@' in i:
    print(i)
    line = i.decode("latin-1")
    print(mail_find(line))
#print(i)
# Out:
# b'                1/2 De Palavras - Centro de Forma\xe7\xe3o Profissional, lda.\r<BR>Rua da Igreja, Lote 682 Fern\xe3o Ferro\r<BR>Tel. 212 121 722 | 967 913 419\r<BR><a target=\'_blank\' href="http://www.ummeiodepalavras.pt">www.ummeiodepalavras.pt</a> | <a href="mailto:geral@ummeiodepalavras.pt?subject=Resposta Anuncio Net-Empregos: CURSO DE PRIMEIROS SOCORROS" title="clicar aqui para se candidatar">geral@ummeiodepalavras.pt</a>  \r<BR>\r\n'
# geral@ummeiodepalavras.pt

# %%
for i in ls:
  print(i)
# Out:
# b'\r\n'
# b'\r\n'
# b'<!DOCTYPE html>\r\n'
# b'<html lang="pt-pt">\r\n'
# b'<head>\r\n'
# b'    <!-- Global site tag (gtag.js) - Google Analytics -->\r\n'
# b'<script async src="https://www.googletagmanager.com/gtag/js?id=UA-175073-3"></script>\r\n'
# b'<script>\r\n'
# b'  window.dataLayer = window.dataLayer || [];\r\n'
# b'  function gtag(){dataLayer.push(arguments);}\r\n'
# b"  gtag('js', new Date());\r\n"
# b'\r\n'
# b"  gtag('config', 'UA-175073-3');\r\n"
# b"  gtag('config', 'AW-1068175425');\r\n"
# b'</script>\r\n'
# b'\r\n'
# b'    <title>CURSO DE PRIMEIROS SOCORROS - 1/2 de Palavras-Apoio Escolar e Forma\xe7\xe3o Profiss. </title>\r\n'
# b'        <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n'
# b'\r\n'
# b'    <meta http-equiv="content-type" content="text/html; charset=ISO-8859-1" />\r\n'
# b'    <meta http-equiv="content-language" content="pt-pt" />\r\n'
# b'\r\n'
# b'    <meta charset="ISO-8859-1">\r\n'
# b'\r\n'
# b'    <!-- External CSS libraries -->\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/css/bootstrap.min.css">\r\n'
# b'    <!-- <link rel="stylesheet" type="text/css" href="/css/animate.min.css"> -->\r\n'
# b'    <!-- <link rel="stylesheet" type="text/css" href="/css/bootstrap-submenu.css"> -->\r\n'
# b'\r\n'
# b'    <!-- <link rel="stylesheet" type="text/css" href="/css/bootstrap-select.min.css"> -->\r\n'
# b'    <!-- <link rel="stylesheet" type="text/css" href="/css/magnific-popup.css"> -->\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/fonts/font-awesome/css/font-awesome.min.css">\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/fonts/flaticon/font/flaticon.css">\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/fonts/linearicons/style.css">\r\n'
# b'    <link rel="stylesheet" type="text/css"  href="/css/jquery.mCustomScrollbar.css">\r\n'
# b'\r\n'
# b'    <!-- Custom stylesheet -->\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/css/style.css">\r\n'
# b'    <link rel="stylesheet" type="text/css" id="style_sheet" href="/css/skins/midnight-blue.css">\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/css/net-empregos.css">\r\n'
# b'\r\n'
# b'    <!-- Favicon icon -->\r\n'
# b'    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\r\n'
# b'    <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\r\n'
# b'    <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\r\n'
# b'    <link rel="icon" type="image/png" sizes="144x144" href="/favicon-144x144.png">\r\n'
# b'    <!-- \r\n'
# b'    <link rel="manifest" href="/site.webmanifest">\r\n'
# b'    -->\r\n'
# b'    <meta name="msapplication-TileColor" content="#da532c">\r\n'
# b'    <meta name="theme-color" content="#ffffff">\r\n'
# b'\r\n'
# b'\r\n'
# b'    <!-- Google fonts -->\r\n'
# b'    <link href="https://fonts.googleapis.com/css?family=Nunito:300,400,600,700,800,900%7CRaleway:300,400,500,600,700&display=swap" rel="stylesheet">\r\n'
# b'\r\n'
# b'    <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->\r\n'
# b'    <link rel="stylesheet" type="text/css" href="/css/ie10-viewport-bug-workaround.css">\r\n'
# b'\r\n'
# b"    <!-- Just for debugging purposes. Don't actually copy these 2 lines! -->\r\n"
# b'    <!--[if lt IE 9]><script  src="/js/ie8-responsive-file-warning.js"></script><![endif]-->\r\n'
# b'    <script  src="/js/ie-emulation-modes-warning.js"></script>\r\n'
# b'\r\n'
# b'    <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n'
# b'    <!--[if lt IE 9]>\r\n'
# b'    <script  src="/js/html5shiv.min.js"></script>\r\n'
# b'    <script  src="/js/respond.min.js"></script>\r\n'
# b'    <![endif]-->\r\n'
# b'\r\n'
# b'    <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\r\n'
# b'\r\n'
# b'    <!-- Ad Manager Google -->\r\n'
# b'    <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\r\n'
# b'\r\n'
# b'    <script>\r\n'
# b'    window.googletag = window.googletag || {cmd: []};\r\n'
# b'    googletag.cmd.push(function() {\r\n'
# b"        googletag.defineSlot('/1026826/Net-Empregos-Quadrado-Mobile', [[300, 250], [250, 250], [250, 360], [336, 280]], 'div-gpt-ad-1620264316617-0').addService(googletag.pubads());\r\n"
# b'        googletag.pubads().enableSingleRequest();\r\n'
# b'        googletag.enableServices();\r\n'
# b'    });\r\n'
# b'    </script>\r\n'
# b'\r\n'
# b'    <script>\r\n'
# b'    window.googletag = window.googletag || {cmd: []};\r\n'
# b'    googletag.cmd.push(function() {\r\n'
# b"        googletag.defineSlot('/1026826/Net-Empregos-Coluna-Desktop', [[300, 600], [240, 400], [300, 250], [250, 250]], 'div-gpt-ad-1620661133451-0').addService(googletag.pubads());\r\n"
# b'        googletag.pubads().enableSingleRequest();\r\n'
# b'        googletag.enableServices();\r\n'
# b'    });\r\n'
# b'    </script>\r\n'
# b'\r\n'
# b'    <script>\r\n'
# b'    window.googletag = window.googletag || {cmd: []};\r\n'
# b'    googletag.cmd.push(function() {\r\n'
# b"        var responsiveAdSlot = googletag.defineSlot('/1026826/Net-Empregos-Quadrado-All-Sizes', [[930, 180], [250, 360], [980, 120], [336, 280], [250, 250], [300, 250], [750, 200], [970, 250], [728, 90], [750, 300]], 'div-gpt-ad-1622029190076-0').addService(googletag.pubads());\r\n"
# b'        var mapping = googletag.sizeMapping()\r\n'
# b'                    .addSize([991, 0], [[970, 250], [750, 200], [750, 300], [980, 120], [930, 180], [728, 90]])\r\n'
# b'                    .addSize([250, 0], [300, 250], [250, 250], [250, 360], [336, 280])\r\n'
# b'                    .addSize([0, 0], [])\r\n'
# b'                    .build();\r\n'
# b'        responsiveAdSlot.defineSizeMapping(mapping);        \r\n'
# b'        \r\n'
# b'        googletag.pubads().enableSingleRequest();\r\n'
# b'        googletag.enableServices();\r\n'
# b'    });\r\n'
# b'    </script>\r\n'
# b'\r\n'
# b'     <!-- Google Search Ads -->\r\n'
# b'    <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>\r\n'
# b'    <script type="text/javascript" charset="utf-8">\r\n'
# b"    (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(\r\n"
# b"    arguments)},g[o]['t']=1*new Date})(window,'_googCsa');\r\n"
# b'    </script>\r\n'
# b'\r\n'
# b'\r\n'
# b'    <script>(function(){/*\r\n'
# b'\r\n'
# b'    Copyright The Closure Library Authors.\r\n'
# b'    SPDX-License-Identifier: Apache-2.0\r\n'
# b'    */\r\n'
# b'    \'use strict\';var g=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},l=this||self,m=/^[\\w+/_-]+[=]{0,2}$/,p=null,q=function(){},r=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";\r\n'
# b'    if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b},u=function(a,b){function c(){}c.prototype=b.prototype;a.prototype=new c;a.prototype.constructor=a};var v=function(a,b){Object.defineProperty(l,a,{configurable:!1,get:function(){return b},set:q})};var y=function(a,b){this.b=a===w&&b||"";this.a=x},x={},w={};var aa=function(a,b){a.src=b instanceof y&&b.constructor===y&&b.a===x?b.b:"type_error:TrustedResourceUrl";if(null===p)b:{b=l.document;if((b=b.querySelector&&b.querySelector("script[nonce]"))&&(b=b.nonce||b.getAttribute("nonce"))&&m.test(b)){p=b;break b}p=""}b=p;b&&a.setAttribute("nonce",b)};var z=function(){return Math.floor(2147483648*Math.random()).toString(36)+Math.abs(Math.floor(2147483648*Math.random())^+new Date).toString(36)};var A=function(a,b){b=String(b);"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)},B=function(a){this.a=a||l.document||document};B.prototype.appendChild=function(a,b){a.appendChild(b)};var C=function(a,b,c,d,e,f){try{var k=a.a,h=A(a.a,"SCRIPT");h.async=!0;aa(h,b);k.head.appendChild(h);h.addEventListener("load",function(){e();d&&k.head.removeChild(h)});h.addEventListener("error",function(){0<c?C(a,b,c-1,d,e,f):(d&&k.head.removeChild(h),f())})}catch(n){f()}};var ba=l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"),ca=l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="),da=l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"),ea=function(a,b,c){this.b=a;this.f=new B(this.b);this.a=null;this.c=[];this.g=!1;this.i=b;this.h=c},F=function(a){if(a.b.body&&!a.g){var b=\r\n'
# b'    function(){D(a);l.setTimeout(function(){return E(a,3)},50)};C(a.f,a.i,2,!0,function(){l[a.h]||b()},b);a.g=!0}},D=function(a){for(var b=G(1,5),c=0;c<b;c++){var d=H(a);a.b.body.appendChild(d);a.c.push(d)}b=H(a);b.style.bottom="0";b.style.left="0";b.style.position="fixed";b.style.width=G(100,110).toString()+"%";b.style.zIndex=G(2147483544,2147483644).toString();b.style["background-color"]=I(249,259,242,252,219,229);b.style["box-shadow"]="0 0 12px #888";b.style.color=I(0,10,0,10,0,10);b.style.display=\r\n'
# b'    "flex";b.style["justify-content"]="center";b.style["font-family"]="Roboto, Arial";c=H(a);c.style.width=G(80,85).toString()+"%";c.style.maxWidth=G(750,775).toString()+"px";c.style.margin="24px";c.style.display="flex";c.style["align-items"]="flex-start";c.style["justify-content"]="center";d=A(a.f.a,"IMG");d.className=z();d.src=ba;d.style.height="24px";d.style.width="24px";d.style["padding-right"]="16px";var e=H(a),f=H(a);f.style["font-weight"]="bold";f.textContent=ca;var k=H(a);k.textContent=da;J(a,\r\n'
# b'    e,f);J(a,e,k);J(a,c,d);J(a,c,e);J(a,b,c);a.a=b;a.b.body.appendChild(a.a);b=G(1,5);for(c=0;c<b;c++)d=H(a),a.b.body.appendChild(d),a.c.push(d)},J=function(a,b,c){for(var d=G(1,5),e=0;e<d;e++){var f=H(a);b.appendChild(f)}b.appendChild(c);c=G(1,5);for(d=0;d<c;d++)e=H(a),b.appendChild(e)},G=function(a,b){return Math.floor(a+Math.random()*(b-a))},I=function(a,b,c,d,e,f){return"rgb("+G(Math.max(a,0),Math.min(b,255)).toString()+","+G(Math.max(c,0),Math.min(d,255)).toString()+","+G(Math.max(e,0),Math.min(f,\r\n'
# b'    255)).toString()+")"},H=function(a){a=A(a.f.a,"DIV");a.className=z();return a},E=function(a,b){0>=b||null!=a.a&&0!=a.a.offsetHeight&&0!=a.a.offsetWidth||(fa(a),D(a),l.setTimeout(function(){return E(a,b-1)},50))},fa=function(a){var b=a.c;var c="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];b=c?c.call(b):{next:g(b)};for(c=b.next();!c.done;c=b.next())(c=c.value)&&c.parentNode&&c.parentNode.removeChild(c);a.c=[];(b=a.a)&&b.parentNode&&b.parentNode.removeChild(b);a.a=null};var ia=function(a,b,c,d,e){var f=ha(c),k=function(n){n.appendChild(f);l.setTimeout(function(){f?(0!==f.offsetHeight&&0!==f.offsetWidth?b():a(),f.parentNode&&f.parentNode.removeChild(f)):a()},d)},h=function(n){document.body?k(document.body):0<n?l.setTimeout(function(){h(n-1)},e):b()};h(3)},ha=function(a){var b=document.createElement("div");b.className=a;b.style.width="1px";b.style.height="1px";b.style.position="absolute";b.style.left="-10000px";b.style.top="-10000px";b.style.zIndex="-10000";return b};var K={},L=null;var M=function(){},N="function"==typeof Uint8Array,O=function(a,b){a.b=null;b||(b=[]);a.j=void 0;a.f=-1;a.a=b;a:{if(b=a.a.length){--b;var c=a.a[b];if(!(null===c||"object"!=typeof c||Array.isArray(c)||N&&c instanceof Uint8Array)){a.g=b-a.f;a.c=c;break a}}a.g=Number.MAX_VALUE}a.i={}},P=[],Q=function(a,b){if(b<a.g){b+=a.f;var c=a.a[b];return c===P?a.a[b]=[]:c}if(a.c)return c=a.c[b],c===P?a.c[b]=[]:c},R=function(a,b,c){a.b||(a.b={});if(!a.b[c]){var d=Q(a,c);d&&(a.b[c]=new b(d))}return a.b[c]};\r\n'
# b'    M.prototype.h=N?function(){var a=Uint8Array.prototype.toJSON;Uint8Array.prototype.toJSON=function(){var b;void 0===b&&(b=0);if(!L){L={};for(var c="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""),d=["+/=","+/","-_=","-_.","-_"],e=0;5>e;e++){var f=c.concat(d[e].split(""));K[e]=f;for(var k=0;k<f.length;k++){var h=f[k];void 0===L[h]&&(L[h]=k)}}}b=K[b];c=[];for(d=0;d<this.length;d+=3){var n=this[d],t=(e=d+1<this.length)?this[d+1]:0;h=(f=d+2<this.length)?this[d+2]:0;k=n>>2;n=(n&\r\n'
# b'    3)<<4|t>>4;t=(t&15)<<2|h>>6;h&=63;f||(h=64,e||(t=64));c.push(b[k],b[n],b[t]||"",b[h]||"")}return c.join("")};try{return JSON.stringify(this.a&&this.a,S)}finally{Uint8Array.prototype.toJSON=a}}:function(){return JSON.stringify(this.a&&this.a,S)};var S=function(a,b){return"number"!==typeof b||!isNaN(b)&&Infinity!==b&&-Infinity!==b?b:String(b)};M.prototype.toString=function(){return this.a.toString()};var T=function(a){O(this,a)};u(T,M);var U=function(a){O(this,a)};u(U,M);var ja=function(a,b){this.c=new B(a);var c=R(b,T,5);c=new y(w,Q(c,4)||"");this.b=new ea(a,c,Q(b,4));this.a=b},ka=function(a,b,c,d){b=new T(b?JSON.parse(b):null);b=new y(w,Q(b,4)||"");C(a.c,b,3,!1,c,function(){ia(function(){F(a.b);d(!1)},function(){d(!0)},Q(a.a,2),Q(a.a,3),Q(a.a,1))})};var la=function(a,b){V(a,"internal_api_load_with_sb",function(c,d,e){ka(b,c,d,e)});V(a,"internal_api_sb",function(){F(b.b)})},V=function(a,b,c){a=l.btoa(a+b);v(a,c)},W=function(a,b,c){for(var d=[],e=2;e<arguments.length;++e)d[e-2]=arguments[e];e=l.btoa(a+b);e=l[e];if("function"==r(e))e.apply(null,d);else throw Error("API not exported.");};var X=function(a){O(this,a)};u(X,M);var Y=function(a){this.h=window;this.a=a;this.b=Q(this.a,1);this.f=R(this.a,T,2);this.g=R(this.a,U,3);this.c=!1};Y.prototype.start=function(){ma();var a=new ja(this.h.document,this.g);la(this.b,a);na(this)};\r\n'
# b'    var ma=function(){var a=function(){if(!l.frames.googlefcPresent)if(document.body){var b=document.createElement("iframe");b.style.display="none";b.style.width="0px";b.style.height="0px";b.style.border="none";b.style.zIndex="-1000";b.style.left="-1000px";b.style.top="-1000px";b.name="googlefcPresent";document.body.appendChild(b)}else l.setTimeout(a,5)};a()},na=function(a){var b=Date.now();W(a.b,"internal_api_load_with_sb",a.f.h(),function(){var c;var d=a.b,e=l[l.btoa(d+"loader_js")];if(e){e=l.atob(e);\r\n'
# b'    e=parseInt(e,10);d=l.btoa(d+"loader_js").split(".");var f=l;d[0]in f||"undefined"==typeof f.execScript||f.execScript("var "+d[0]);for(;d.length&&(c=d.shift());)d.length?f[c]&&f[c]!==Object.prototype[c]?f=f[c]:f=f[c]={}:f[c]=null;c=Math.abs(b-e);c=1728E5>c?0:c}else c=-1;0!=c&&(W(a.b,"internal_api_sb"),Z(a,Q(a.a,6)))},function(c){Z(a,c?Q(a.a,4):Q(a.a,5))})},Z=function(a,b){a.c||(a.c=!0,a=new l.XMLHttpRequest,a.open("GET",b,!0),a.send())};(function(a,b){l[a]=function(c){for(var d=[],e=0;e<arguments.length;++e)d[e-0]=arguments[e];l[a]=q;b.apply(null,d)}})("__d3lUW8vwsKlB__",function(a){"function"==typeof window.atob&&(a=window.atob(a),a=new X(a?JSON.parse(a):null),(new Y(a)).start())});}).call(this);\r\n'
# b'\r\n'
# b'    window.__d3lUW8vwsKlB__("...");</script>\r\n'
# b'    \r\n'
# b'    <!-- \r\n'
# b'    <script defer src="https://progressier.com/client/script.js?id=wQulXKCiYDS7HcaEvmgj"></script>\r\n'
# b'     -->\r\n'
# b'     \r\n'
# b'\r\n'
# b'    <meta NAME="description" CONTENT=" CURSO DE PRIMEIROS SOCORROS - Venha aprender a salvar vidas!\r\n'
# b'\r\n'
# b' \r\n'
# b' \r\n'
# b' \r\n'
# b' \r\n'
# b'\r\n'
# b'">\r\n'
# b'\t<meta NAME="keywords" CONTENT="CURSO DE PRIMEIROS SOCORROS, emprego , empregos , bolsa , jobs , estagios , trabalho , anuncio , an\xfancios , curriculo , dicas , curr\xedculo , oferta , recursos , humanos , formacao , carreira , carreiras ">\r\n'
# b'</head>\r\n'
# b'<body>\r\n'
# b'<div class="page_loader" style="display: none;"></div>\r\n'
# b'<!-- Main header start -->\r\n'
# b'<header class="main-header header-transparent sticky-header header-bg text-color">\r\n'
# b'    <div class="container">\r\n'
# b'        <nav class="navbar navbar-expand-lg navbar-light">\r\n'
# b'\r\n'
# b'            <button onclick="myFunction()" class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">\r\n'
# b'                <span id="SpanIcon" class="fa fa-bars"></span>\r\n'
# b'            </button>\r\n'
# b'\r\n'
# b'            <a class="navbar-brand logo-2" href="/index.asp" style="width: 120px">\r\n'
# b'                <img src="/img/logos/logo_novo_small.png" alt="net-empregos logo">\r\n'
# b'            </a>\r\n'
# b'\r\n'
# b'            <div class="collapse navbar-collapse" id="navbarSupportedContent">\r\n'
# b'                <ul class="navbar-nav header-ml">\r\n'
# b'                    <li class="nav-item active">\r\n'
# b'                        \r\n'
# b'                            <a class="nav-link" href="/index.asp" id="menu-inicio" style="font-weight:bold;color: #dc3545;"><i class="fa fa-search""></i> Procurar Emprego</a>\r\n'
# b'                        \r\n'
# b'                    </li>\r\n'
# b'\r\n'
# b'                    <!--\r\n'
# b'                    <li class="nav-item dropdown">\r\n'
# b'                        <a class="nav-link dropdown-toggle" href="#" id="menu-ofertas" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false"><i class="fa fa-search"></i> Ofertas Emprego</a>\r\n'
# b'                        <ul class="dropdown-menu" aria-labelledby="menu-ofertas">\r\n'
# b'                            <li><a class="dropdown-item" href="/index.asp">Pesquisar Ofertas</a></li>\r\n'
# b'                            <li><a class="dropdown-item" href="/pesquisa-empregos.asp">Ultimas Ofertas</a></li>\r\n'
# b'                            <li><a class="dropdown-item" href="/mais-emprego.asp">Ofertas por Categoria Profissional</a></li>\r\n'
# b'                            <li><a class="dropdown-item" href="/mais-emprego-localidades.asp">Ofertas por Cidades</a></li>\r\n'
# b'                        </ul>\r\n'
# b'                    </li>\r\n'
# b'                    -->\r\n'
# b'\r\n'
# b'                    \r\n'
# b'                        <li class="nav-item dropdown">\r\n'
# b'                            <a class="nav-link dropdown-toggle" href="#" id="menu-candidato" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" style="color: #007bff;"><i class="fa fa-users"></i> Candidato</a>\r\n'
# b'                            <ul class="dropdown-menu dm-2" aria-labelledby="menu-candidato">                            \r\n'
# b'                                <li><a style="font-weight:bold" class="dropdown-item" href="/curriculo.asp"><i class="fa fa-address-card-o"></i> Perfil</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/mudar_pwd_c.asp"><i class="fa fa-user-circle-o"></i> Registo</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/favoritos_c.asp"><i class="fa fa-heart-o"></i> Favoritos</a></li>\r\n'
# b'                                \r\n'
# b'                            </ul>\r\n'
# b'                        </li>\r\n'
# b'                    \r\n'
# b'                        <li class="nav-item dropdown">\r\n'
# b'                            <a class="nav-link dropdown-toggle" href="#" id="menu-empresa" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" style="color: #007bff;"><i class="flaticon-branch"></i> Empresa</a>\r\n'
# b'                            <ul class="dropdown-menu dm-2" aria-labelledby="menu-empresa">\r\n'
# b'                                <li><a style="font-weight:bold" class="dropdown-item" href="/anuncio.asp"><i class="fa fa-plus-square"></i> Publicar Oferta Gr\xe1tis</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/anuncios.asp"><i class="fa fa-list-ul"></i> Ofertas Activas</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/anuncios_arquivo.asp"><i class="fa fa-folder-open-o"></i> Ofertas Arquivadas</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/anuncios_formacao.asp"><i class="fa fa-graduation-cap"></i> Ofertas de Forma\xe7\xe3o</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/mudar_pwd_e.asp"><i class="fa fa-user-circle-o"></i> Registo</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/empresa_info.asp"><i class="fa fa-info-circle"></i> Logo / Info + API</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/anuncio-destaque-pack.asp"><i class="fa fa-star"></i> <span class="badge badge-danger">N </span> Pacotes Destaques</a></li>\r\n'
# b'                                <li><a class="dropdown-item" href="/facturas-movimentos.asp"><i class="fa fa-file-text-o"></i> Facturas</a></li>\r\n'
# b'                                \r\n'
# b'                            </ul>\r\n'
# b'                        </li>\r\n'
# b'                    \r\n'
# b'\r\n'
# b'                    <li class="nav-item">\r\n'
# b'                        <a class="nav-link" href="/formacao.asp" id="menu-formacao" style="color: #007bff;"><i class="fa fa-graduation-cap"></i> Forma\xe7\xe3o</a>\r\n'
# b'                    </li>\r\n'
# b'                    <li class="nav-item">\r\n'
# b'                        <a class="nav-link" href="/contactos.asp" id="menu-contactos"><i class="fa fa-envelope"></i> Contactos</a>\r\n'
# b'                    </li>                    \r\n'
# b'                    \r\n'
# b'                    <!--\r\n'
# b'                    <li class="nav-item">\r\n'
# b'                        <a class="nav-link" href="https://install.fyi/net-empregos" id="menu-install"><i class="fa fa-cloud-download"></i> Instalar APP</a>\r\n'
# b'                    </li>                    \r\n'
# b'                    -->\r\n'
# b'                </ul>\r\n'
# b'\r\n'
# b'                \r\n'
# b'                    <ul class="navbar-nav ml-auto">\r\n'
# b'                        <li class="nav-item dropdown">\r\n'
# b'                            <a class="nav-link dropdown-toggle" href="#" id="menu-login" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" style="color: #c40000;"><i class="fa fa-user" ></i> Login</a>\r\n'
# b'                            <ul class="dropdown-menu dm-2" aria-labelledby="menu-login">\r\n'
# b'                                <li><a style="color: #c40000;" class="dropdown-item" href="/loginc.asp"><i class="fa fa-users"></i> Candidato</a></li>\r\n'
# b'                                <li><a style="color: #c40000;" class="dropdown-item" href="/LoginE.asp"><i class="flaticon-branch"></i> Empresa</a></li>\r\n'
# b'                            </ul>\r\n'
# b'                        </li>\r\n'
# b'                        <li class="nav-item dropdown">\r\n'
# b'                            <a class="nav-link dropdown-toggle" href="#" id="menu-registar" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" style="color: #c40000;"><i class="fa fa-user-plus"></i> Registar</a>\r\n'
# b'                            <ul class="dropdown-menu dm-2" aria-labelledby="menu-registar">\r\n'
# b'                                <li><a style="color: #c40000;" class="dropdown-item" href="/registar_novo.asp"><i class="fa fa-users"></i> Candidato</a></li>\r\n'
# b'                                <li><a style="color: #c40000;" class="dropdown-item" href="/registar_empresa_2.asp"><i class="flaticon-branch"></i> Empresa</a></li>\r\n'
# b'                            </ul>\r\n'
# b'                        </li>\r\n'
# b'                    </ul>\r\n'
# b'                \r\n'
# b'    \r\n'
# b'                <a href="/index.asp" style="width: 50px;">\r\n'
# b'                    <img src="/img/logos/blank.png" alt="logo">\r\n'
# b'                </a>\r\n'
# b'                \r\n'
# b'            </div>\r\n'
# b'        </nav>\r\n'
# b'    </div>\r\n'
# b'</header>\r\n'
# b'<!-- Main header end -->\r\n'
# b'\r\n'
# b'<script type="text/javascript">\r\n'
# b'function myFunction() {\r\n'
# b'  var x = document.getElementById("SpanIcon");\r\n'
# b'  if (x.className === "fa fa-bars") {\r\n'
# b'    x.className = "fa fa-times";\r\n'
# b'  } else {\r\n'
# b'    x.className = "fa fa-bars";\r\n'
# b'  }\r\n'
# b'}\r\n'
# b'</script>\r\n'
# b'\r\n'
# b'\r\n'
# b'<!-- Job details page start -->\r\n'
# b'<div class="job-details-page content-area">\r\n'
# b'    <div class="container">    \t\r\n'
# b'        <div class="row">\r\n'
# b'            <div class="col-lg-8 col-md-12">\r\n'
# b'                <!-- Main item start -->\r\n'
# b'            \r\n'
# b'                <div class="main-item">\r\n'
# b'                    <div class="description">\r\n'
# b'                  \r\n'
# b'                        <h1 class="title">CURSO DE PRIMEIROS SOCORROS</h1>\r\n'
# b'                        <div class="candidate-listing-footer">\r\n'
# b'                            <ul>\r\n'
# b'                                    \r\n'
# b'                                <li><i class="flaticon-work" style="color: #007bff;"></i> 1/2 de Palavras-Apoio Escolar e Forma\xe7\xe3o Profiss.</li>                                \r\n'
# b'                                    \r\n'
# b'                                <li><i class="flaticon-pin" style="color: #d81e1e;"></i> Fern\xe3o Ferro | Fogueteiro</li>\r\n'
# b'                                \r\n'
# b'                                <BR>\r\n'
# b'                                <li><i class="flaticon-calendar" style="color: #f19d35;"></i> inscri\xe7\xf5es abertas!    \r\n'
# b'                                &nbsp;-&nbsp;<b>Dura\xe7\xe3o:</b> 6 HORAS    \r\n'
# b'                                &nbsp;-&nbsp;<b>Hor\xe1rio:</b>  \r\n'
# b'                                </li>\r\n'
# b'                                    \r\n'
# b'                                <BR>\r\n'
# b'                                <li><i class="flaticon-discount"></i> valor isento de iva: 60\x80</li>\r\n'
# b'                                \r\n'
# b'                            </ul>\r\n'
# b'                        </div>\r\n'
# b'                    </div>\r\n'
# b'                </div>\r\n'
# b'                <hr class="hr-boder">\r\n'
# b'                <!-- job description start -->\r\n'
# b'                <div class="job-description mb-40">\r\n'
# b'\t\t\t\t\t<div class="my-1">\r\n'
# b'\t\t\t\t\t\t\r\n'
# b'\r\n'
# b'\t\t<!-- Net-Empregos -- Quadrado -->\r\n'
# b'\t\t<ins class="adsbygoogle"\r\n'
# b'\t\t\tstyle="display:block"\r\n'
# b'\t\t\tdata-full-width-responsive="true"\r\n'
# b'\t\t\tdata-ad-client="ca-pub-9487857958358554"\t\r\n'
# b'\t\t\tdata-ad-slot="2538807626"\r\n'
# b'\t\t\tdata-ad-format="auto"\r\n'
# b'\t\t\tdata-full-width-responsive="true"></ins>\r\n'
# b'\t\t<script>\r\n'
# b'\t\t(adsbygoogle = window.adsbygoogle || []).push({});\r\n'
# b'\t\t</script>\t\r\n'
# b'\t\t\t\t\r\n'
# b'\t\r\n'
# b'\t\t\t\t\t</div>\t\t\r\n'
# b'                </div>\r\n'
# b'                \r\n'
# b'                <h3 class="heading-2">Descri\xe7\xe3o do Curso:</h3>     \r\n'
# b'                <br>\r\n'
# b'                <p>           \r\n'
# b'                Venha aprender a salvar vidas!\r<BR>\r<BR> \r<BR> \r<BR> \r<BR> \r<BR>\r<BR>\r\n'
# b'                </p>\r\n'
# b'                \r\n'
# b'                \r\n'
# b'                <hr class="hr-boder">\r\n'
# b'                \r\n'
# b'                \r\n'
# b'                <h6><b>Contactos p/Informa\xe7\xf5es e Inscri\xe7\xf5es:</b></h6>\r\n'
# b'                <p>\r\n'
# b'                1/2 De Palavras - Centro de Forma\xe7\xe3o Profissional, lda.\r<BR>Rua da Igreja, Lote 682 Fern\xe3o Ferro\r<BR>Tel. 212 121 722 | 967 913 419\r<BR><a target=\'_blank\' href="http://www.ummeiodepalavras.pt">www.ummeiodepalavras.pt</a> | <a href="mailto:geral@ummeiodepalavras.pt?subject=Resposta Anuncio Net-Empregos: CURSO DE PRIMEIROS SOCORROS" title="clicar aqui para se candidatar">geral@ummeiodepalavras.pt</a>  \r<BR>\r\n'
# b'                </p>\r\n'
# b'                \r\n'
# b'\r\n'
# b'            <hr class="hr-boder">\r\n'
# b'            \r\n'
# b'            \r\n'
# b'                <div class="job-description mb-40">\r\n'
# b'                    <div class="my-1">                    \r\n'
# b'                        \r\n'
# b'\r\n'
# b'\t\t<!-- Net-Empregos -- Quadrado -->\r\n'
# b'\t\t<ins class="adsbygoogle"\r\n'
# b'\t\t\tstyle="display:block"\r\n'
# b'\t\t\tdata-full-width-responsive="true"\r\n'
# b'\t\t\tdata-ad-client="ca-pub-9487857958358554"\t\r\n'
# b'\t\t\tdata-ad-slot="2538807626"\r\n'
# b'\t\t\tdata-ad-format="auto"\r\n'
# b'\t\t\tdata-full-width-responsive="true"></ins>\r\n'
# b'\t\t<script>\r\n'
# b'\t\t(adsbygoogle = window.adsbygoogle || []).push({});\r\n'
# b'\t\t</script>\t\r\n'
# b'\t\t\t\t\r\n'
# b'\t                    \r\n'
# b'                    </div>\t\t\r\n'
# b'                </div>\r\n'
# b'            \r\n'
# b'            \r\n'
# b'            <div class="text-center my-5">\r\n'
# b'            \t<button id="btn-voltar" class="btn btn-md button-theme">Voltar<i class="fa fa-arrow-circle-left pl-1"></i></button>\r\n'
# b'            </div>                        \r\n'
# b'            </div>\r\n'
# b'            <div class="col-lg-4 col-md-12">\r\n'
# b'            \t<div id="ads-300x600-2" class="ads-300x600" style="min-width: 300px;">\t\t\t\t\t\r\n'
# b'                    \t\t\r\n'
# b'\r\n'
# b'\t\t<!-- Net-Empregos -- Coluna -->\r\n'
# b'\t\t<ins class="adsbygoogle"\r\n'
# b'\t\t\tstyle="display:block"\r\n'
# b'\t\t\tdata-ad-client="ca-pub-9487857958358554"\r\n'
# b'\t\t\tdata-ad-slot="6131120239"\r\n'
# b'\t\t\tdata-ad-format="auto"\r\n'
# b'\t\t\tdata-full-width-responsive="true"></ins>\t\t\t\r\n'
# b'\t\t<script>\r\n'
# b'\t\t\t(adsbygoogle = window.adsbygoogle || []).push({});\r\n'
# b'\t\t</script>\r\n'
# b'\t\t<br>\r\n'
# b'\r\n'
# b'\t\r\n'
# b'                </div>\r\n'
# b'                \r\n'
# b'                    <div id="ads-300x600-2" class="ads-300x600">    \r\n'
# b'                        \r\n'
# b'\r\n'
# b'    <!-- /1026826/Net-Empregos-Coluna-Desktop -->\r\n'
# b"    <div id='div-gpt-ad-1620661133451-0'>\r\n"
# b'    <script>\r\n'
# b"        googletag.cmd.push(function() { googletag.display('div-gpt-ad-1620661133451-0'); });\r\n"
# b'    </script>\r\n'
# b'    </div>\r\n'
# b'\r\n'
# b'\r\n'
# b'                    </div>\r\n'
# b'                               \r\n'
# b'            </div>\r\n'
# b'        </div>\r\n'
# b'    </div>\r\n'
# b'</div>\r\n'
# b'<!-- Footer start -->\r\n'
# b'<footer class="footer" style="background: none; background-color: #3f88f5; color: #fff">\r\n'
# b'    <div class="container footer-inner">\r\n'
# b'        <div class="row">\r\n'
# b'            <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item clearfix">\r\n'
# b'                    <img src="/img/logos/logo_white.png" alt="logo" class="f-logo" style="height:60px">\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'            <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item">\r\n'
# b'                    <h4><b>Net-Empregos</b></h4>\r\n'
# b'                    <br>\r\n'
# b'                    <ul class="links">\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/sobre.asp">Acerca</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/politica-privacidade.asp">Pol\xedtica de Privacidade e Termos de Utiliza\xe7\xe3o</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/publicidade_info.asp">Publicidade</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/contactos.asp">Contactos</a>\r\n'
# b'                        </li>\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'            <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item">\r\n'
# b'                    <h4><b>Ofertas Emprego</b></h4>\r\n'
# b'                    <br>\r\n'
# b'                    <ul class="links">\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/pesquisa-empregos.asp">Ultimas Ofertas</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/mais-emprego-localidades.asp">Ofertas por Cidades</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/mais-emprego.asp">Ofertas por Categoria</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/mais-emprego-cidades-categorias-html.asp">Ofertas por Distrito e Categoria</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/lista-top-pesquisas.html.asp">Pesquisas Populares</a>\r\n'
# b'                        </li>\r\n'
# b'\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'            <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item">\r\n'
# b'                    <h4><b>Candidato</b></h4>\r\n'
# b'                    <br>\r\n'
# b'                    <ul class="links">\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/loginc.asp">Login Candidato</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/registar_novo.asp">Registar Candidato</a>\r\n'
# b'                        </li>\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'            <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item clearfix">\r\n'
# b'                    <h4><b>Empresa</b></h4>\r\n'
# b'                    <br>\r\n'
# b'                     <ul class="links">\r\n'
# b'                         <li>\r\n'
# b'                            <a href="/anuncio.asp">Publicar Oferta Gr\xe1tis</a>\r\n'
# b'                        </li>                         \r\n'
# b'                        <li>\r\n'
# b'                            <a href="/LoginE.asp">Login Empresa</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a href="/registar_empresa_2.asp">Registar Empresa</a>\r\n'
# b'                        </li>\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'             <div class="col-xl-2 col-lg-2 col-md-4 col-sm-6">\r\n'
# b'                <div class="footer-item clearfix">\r\n'
# b'                    <h4><b>Siga-nos!</b></h4>\r\n'
# b'                    <br>\r\n'
# b'                     <ul class="links">\r\n'
# b'                        <li>\r\n'
# b'                            <a rel="noreferrer" href="https://www.facebook.com/netempregos" target="_blank">Facebook</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a rel="noreferrer" href="https://twitter.com/netempregos" target="_blank">Twitter</a>\r\n'
# b'                        </li>\r\n'
# b'                        <li>\r\n'
# b'                            <a rel="noreferrer" href="https://www.linkedin.com/company/net-empregos" target="_blank">LinkedIn</a>\r\n'
# b'                        </li>\r\n'
# b'                         <li>\r\n'
# b'                            <a rel="noreferrer" href="https://feeds.feedburner.com/Net-empregos" target="_blank">RSS Feed</a>\r\n'
# b'                        </li>\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'        </div>\r\n'
# b'    </div>\r\n'
# b'    <div class="sub-footer">\r\n'
# b'        <div class="container">\r\n'
# b'            <div class="row">\r\n'
# b'                <div class="col-xl-9 col-lg-9 col-md-12">\r\n'
# b'                    <p class="copy">2021 <a href="#">Net-Empregos | Cen\xe1rio Virtual Lda</a></p>\r\n'
# b'                </div>\r\n'
# b'                <div class="col-xl-3 col-lg-3 col-md-12">\r\n'
# b'                    <ul class="social-list clearfix">\r\n'
# b'                        <li><a rel="noreferrer" href="https://www.facebook.com/netempregos" target="_blank"><i class="fa fa-facebook"></i></a></li>\r\n'
# b'                        <li><a rel="noreferrer" href="https://twitter.com/netempregos" target="_blank"><i class="fa fa-twitter"></i></a></li>\r\n'
# b'                        <li><a rel="noreferrer" href="https://www.linkedin.com/company/net-empregos" target="_blank"><i class="fa fa-linkedin-square"></i></a></li>                        \r\n'
# b'                        <li><a rel="noreferrer" href="https://feeds.feedburner.com/Net-empregos" target="_blank"><i class="fa fa-rss"></i></a></li>\r\n'
# b'                    </ul>\r\n'
# b'                </div>\r\n'
# b'            </div>\r\n'
# b'        </div>\r\n'
# b'    </div>\r\n'
# b'</footer>\r\n'
# b'<!-- Footer end -->\r\n'
# b'\r\n'
# b'<script src="/js/jquery-2.2.0.min.js"></script>\r\n'
# b'<script src="/js/popper.min.js"></script>\r\n'
# b'<script src="/js/bootstrap.min.js"></script>\r\n'
# b'<script  src="/js/bootstrap-submenu.js"></script>\r\n'
# b'<script  src="/js/bootstrap-select.min.js"></script>\r\n'
# b'<script  src="/js/jquery.easing.1.3.js"></script>\r\n'
# b'<script  src="/js/jquery.scrollUp.js"></script>\r\n'
# b'<script  src="/js/jquery.mCustomScrollbar.concat.min.js"></script>\r\n'
# b'<script  src="/js/moment.min.js"></script>\r\n'
# b'<!--<script  src="/js/jquery.filterizr.js"></script>-->\r\n'
# b'<!--<script  src="/js/jquery.magnific-popup.min.js"></script>-\r\n'
# b'<script  src="/js/jquery.countdown.js"></script>-->\r\n'
# b'<script  src="/js/app.js?v=1.01"></script>\r\n'
# b'\r\n'
# b'<!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->\r\n'
# b'<script  src="/js/ie10-viewport-bug-workaround.js"></script>\r\n'
# b'<!-- Custom javascript -->\r\n'
# b'<script  src="/js/ie10-viewport-bug-workaround.js"></script>\r\n'
# b'\r\n'
# b'\r\n'
# b'<script type="text/javascript">\r\n'
# b'\r\n'
# b"\t$('#btn-voltar').on( 'click', function () {                  \r\n"
# b'        window.history.back();\r\n'
# b'    });     \r\n'
# b'\r\n'
# b'</script>  \r\n'
# b'\r\n'
# b'</body>\r\n'
# b'</html>\r\n'
